# %%
import json
from pathlib import Path
from qiskit import qpy

data_dir = Path("../data")

with open(data_dir / "2_circuitsraw_64.qpy", "rb") as f:
    circuits_raw = qpy.load(f)

with open(data_dir / "2_circuits_64.qpy", "rb") as f:
    circuits = qpy.load(f)

with open(data_dir / "2_counts_64.json", "r", encoding="utf-8") as f:
    counts = json.load(f)

print("raw circuits:", len(circuits_raw))
print("transpiled circuits:", len(circuits))
print("counts entries:", len(counts))

print(circuits_raw[0].draw("text"))
print(circuits_raw[16].draw("text"))
print(circuits_raw[32].draw("text"))
print(circuits_raw[48].draw("text"))
# Out:
# ---------------------------------------------------------------------------
# CircuitError                              Traceback (most recent call last)
# Cell In[1], line 11
#       7 with open(data_dir / "2_circuitsraw_64.qpy", "rb") as f:
#       8     circuits_raw = qpy.load(f)
#       9
#      10 with open(data_dir / "2_circuits_64.qpy", "rb") as f:
# ---> 11     circuits = qpy.load(f)
#      12
#      13 with open(data_dir / "2_counts_64.json", "r", encoding="utf-8") as f:
#      14     counts = json.load(f)
#
# File d:\Studia\NABLA\Qubit\Odra5-PINN-Tomography\.venv\Lib\site-packages\qiskit\qpy\interface.py:430, in load(file_obj, metadata_deserializer, annotation_factories)
#     426     if data.qpy_version >= 16:
#     427         # Deserialize each program using their byte offsets
#     428         file_obj.seek(program_offsets[i])
#     429     programs.append(
# --> 430         binary_io.read_circuit(
#     431             file_obj,
#     432             data.qpy_version,
#     433             metadata_deserializer=metadata_deserializer,
#     434             use_symengine=use_symengine,
#     435             annotation_factories=annotation_factories,
#     436         )
#     437     )
#     438 return programs
#
# File d:\Studia\NABLA\Qubit\Odra5-PINN-Tomography\.venv\Lib\site-packages\qiskit\qpy\binary_io\circuits.py:1753, in read_circuit(file_obj, version, metadata_deserializer, use_symengine, annotation_factories)
#    1751 custom_operations = _read_custom_operations(file_obj, version, vectors, annotation_state)
#    1752 for _instruction in range(num_instructions):
# -> 1753     _read_instruction(
#    1754         file_obj,
#    1755         circ,
#    1756         out_registers,
#    1757         custom_operations,
#    1758         version,
#    1759         vectors,
#    1760         use_symengine,
#    1761         standalone_var_indices,
#    1762         annotation_state=annotation_state,
#    1763     )
#    1765 # Consume calibrations, but don't use them since pulse gates are not supported as of Qiskit 2.0
#    1766 if version >= 5:
#
# File d:\Studia\NABLA\Qubit\Odra5-PINN-Tomography\.venv\Lib\site-packages\qiskit\qpy\binary_io\circuits.py:579, in _read_instruction(file_obj, circuit, registers, custom_operations, version, vectors, use_symengine, standalone_vars, annotation_state)
#     577             gate.label = label
#     578     else:
# --> 579         gate = gate_class(*params)
#     580 if condition:
#     581     if not isinstance(gate, ControlFlowOp):
#
# File d:\Studia\NABLA\Qubit\Odra5-PINN-Tomography\.venv\Lib\site-packages\qiskit\circuit\delay.py:48, in Delay.__init__(self, duration, unit)
#      34 """
#      35 Args:
#      36     duration: the length of time of the duration. If this is an
#    (...)     45         type that is not timing-based, or the ``unit`` was improperly specified.
#      46 """
#      47 duration, self._unit = self._validate_arguments(duration, unit)
# ---> 48 super().__init__("delay", 1, 0, params=[duration])
#
# File d:\Studia\NABLA\Qubit\Odra5-PINN-Tomography\.venv\Lib\site-packages\qiskit\circuit\instruction.py:102, in Instruction.__init__(self, name, num_qubits, num_clbits, params, label)
#      98 # list of instructions (and their contexts) that this instruction is composed of
#      99 # empty definition means opaque or fundamental instruction
#     100 self._definition = None
# --> 102 self.params = params
#
# File d:\Studia\NABLA\Qubit\Odra5-PINN-Tomography\.venv\Lib\site-packages\qiskit\circuit\instruction.py:279, in Instruction.params(self, parameters)
#     277     self._params.append(single_param)
#     278 else:
# --> 279     self._params.append(self.validate_parameter(single_param))
#
# File d:\Studia\NABLA\Qubit\Odra5-PINN-Tomography\.venv\Lib\site-packages\qiskit\circuit\delay.py:134, in Delay.validate_parameter(self, parameter)
#     132     parameter_int = int(parameter)
#     133     if parameter != parameter_int:
# --> 134         raise CircuitError("Integer duration is expected for 'dt' unit.")
#     135     return parameter_int
#     136 return parameter
#
# CircuitError: "Integer duration is expected for 'dt' unit."
